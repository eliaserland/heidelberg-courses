# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
txtname = "output_density.txt"
data = np.loadtxt(txtname)

print(data.sum())

plt.figure(figsize=(10,10))
plt.imshow(data)
plt.show()
# Out:
# 65536.0
